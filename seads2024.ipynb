# %% [markdown]
# # SEADS 2024: Workshop de Análise de dados com 🐍 Python
#
# O quê compõe um projeto de análise de dados na industria hoje? Existem várias competências envolvidas na análise de dados; em grandes áreas, podemos listar:

# %% [markdown]
# ## DevOps
#  * Automação de deploy
#  * Integração contínua
#  * IaC (Infrastructure as Code)
#
# ## Engenharia de Dados
#  * Ingestão de dados
#  * Transformação, limpeza e qualidade
#  * Armazenamento e disponibilização do dado
#
# ## Ciência de Dados
#  * Análises estatísticas
#  * Modelos de machine learning
#
# ## Engenharia de Machine Learning
#  * Deploy de modelos
#  * Análise de métricas
#  * Alarmes

# %% [markdown]
# # Python 🐍
#
# Lembrete rápido de Python.

# %%
# Listas
[1, 2, 3]

# Booleano
True and False

# Dicionários
{"chave": "valor"}

# Funções
def hello(): return 42

# Variáveis
evento = "SEADS 2024"
print(evento)
# Out:
# SEADS 2024

# %% [markdown]
# # Jupyter Lab 🪐
#
# Esta interface que estamos utilizando se chama Jupyter Lab. Ela nos permite misturar células de texto, escrito em *Markdown*, e células de código.
#
# O Jupyter Lab, ou apenas Jupyter, é muito utilizado no meio para exploração de dados.
#
# * Para executar uma célula, pressione <kbd>Control</kbd> + <kbd>Enter</kbd>
# * Para editar uma célula, clique duas vezes com o mouse 🐁

# %% [markdown]
# # Pandas 🐼
#
# A biblioteca Pandas (https://pandas.pydata.org/) é a porta de entrada para análise de dados! Ela nos permite recortar & picotar o dado de diferentes dimensões, calcular valores agregados (soma, média, desvio padrão, etc.), e também nos ajuda a plotar gráficos.
#
# Podemos pensar no Pandas como um "Excel" em Python.

# %%
import pandas as pd

# %% [markdown]
# ## Series
#
# Uma das abstrações básicas do Pandas é a `Series`, que nada mais é do que uma *coluna* de dados. Toda série possui:
#
# * um tipo de dado (inteiro, ponto flutuante, string, etc.)
# * um índice (que vamos ver mais adiante)
# * um nome

# %%
pd.Series(["terra", "marte", "jupiter"], name="planeta")
# Out:
# 0      terra
# 1      marte
# 2    jupiter
# Name: planeta, dtype: object

# %% [markdown]
# ## DataFrame
#
# Um `DataFrame` nada mais é do que uma coleção de colunas.

# %%
pd.DataFrame(dict(
    planeta=pd.Series(["terra", "marte", "jupiter"]),
    diametro=pd.Series([12_756, 6_794, 142_984]),
))
# Out:
#    planeta  diametro
# 0    terra     12756
# 1    marte      6794
# 2  jupiter    142984

# %% [markdown]
# # Kaggle: Brazilian CS:GO 🔫
#
# Vamos utilizar um conjunto de dados aberto disponibilizado pelo Kaggle de dados do Counter-Strike Brasileiro!
#
# https://www.kaggle.com/datasets/gamersclub/brazilian-csgo-plataform-dataset-by-gamers-club
#
# Esse dataset contém informações como:
# * Quantos bonecos o jogador derrubou na partida
# * Quantas bombas plantadas/defusadas
# * e muitas outras que nem eu sei ainda ;)
#
# Vamos explorar esse dataset juntos?

# %% [markdown]
# ## Trabalhando com arquivos CSV
#
# O Pandas nos permite trabalhar com diversos tipos de arquivos, como
# * CSV
# * Excel
# * JSON
# * Parquet
# * e muitos outros

# %%
pd.read_csv("datasets/tb_lobby_stats_player.csv")
# Out:
#         idLobbyGame  idPlayer  idRoom  qtKill  qtAssist  qtDeath  qtHs  \
# 0                 1         1       1       5         1       16     2
# 1                 2         1       2      24         3       18     6
# 2                 3         2       3       6         4       23     2
# 3                 3       391   27508      10         5       20     4
# 4                 4         2       4       8         4       26     6
# ...             ...       ...     ...     ...       ...      ...   ...
# 184147       172907      2716  178496      21         3       13     5
# 184148       172908      2716  178497      15         1       22     5
# 184149       172909      2716  178498       9         6       23     2
# 184150       172910      2716  178499      15         5       20     6
# 184151       172911      2716  178500      12         6       11     4
#
#         qtBombeDefuse  qtBombePlant  qtTk  ...  qtFlashAssist  qtHitHeadshot  \
# ...
